# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1,10)
x
# Out:
# array([ 1.        ,  1.18367347,  1.36734694,  1.55102041,  1.73469388,
#         1.91836735,  2.10204082,  2.28571429,  2.46938776,  2.65306122,
#         2.83673469,  3.02040816,  3.20408163,  3.3877551 ,  3.57142857,
#         3.75510204,  3.93877551,  4.12244898,  4.30612245,  4.48979592,
#         4.67346939,  4.85714286,  5.04081633,  5.2244898 ,  5.40816327,
#         5.59183673,  5.7755102 ,  5.95918367,  6.14285714,  6.32653061,
#         6.51020408,  6.69387755,  6.87755102,  7.06122449,  7.24489796,
#         7.42857143,  7.6122449 ,  7.79591837,  7.97959184,  8.16326531,
#         8.34693878,  8.53061224,  8.71428571,  8.89795918,  9.08163265,
#         9.26530612,  9.44897959,  9.63265306,  9.81632653, 10.        ])

# %%
y = x ** 2

# %%
plt.plot(x,y)

# %%
x1 = np.random.randn(100,2) * [-2,2]

# %%
x2 = np.random.randn(100,2) * [2,-2]

# %%
print(x1.shape)
# Out:
# (100, 2)

# %%
x = np.vstack((x1,x2))

# %%
x.shape
# Out:
# (200, 2)

# %%
plt.scatter(x1,x2,color="k")#rgb - red,green,blue , cmyk - cyan magenta yellow black

# %%
y = np.zeros(200)

# %%
y[100:] = 1.0

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
plt.hist(x[:  ,0])
# Out:
# (array([ 1.,  9.,  9., 26., 34., 49., 29., 23., 13.,  7.]),
#  array([-5.24459233, -4.25342406, -3.26225578, -2.2710875 , -1.27991922,
#         -0.28875094,  0.70241734,  1.69358562,  2.6847539 ,  3.67592218,
#          4.66709046]),
#  <BarContainer object of 10 artists>)

# %%
x1 = np.random.randn(300,2) * [-2,2]
x2 = np.random.randn(300,2) * [2,-2]
x = np.vstack((x1,x2))

# %%
plt.hist(x[:,1])
plt.show()
